# %%
import os
os.chdir('../')

# %%
import pickle

# %%
with open('adl_reverse_df.pkl', 'rb') as filehandle: 
    selectedAtivosDiasDF = pickle.load(filehandle)

# %%
selectedAtivosDiasDF
# Out:
#      name        date  minFromOpenPercent   freefloat   price  \
# 0    LTBR  2019-10-21           -0.345444   5602946.0  7.4400
# 1    NNDM  2019-10-22           -0.418919  46033103.0  3.7000
# 2    MARA  2019-10-22           -0.308642  41007327.0  1.6200
# 3    OPGN  2019-10-23           -0.395176  20114931.0  5.3900
# 4    NNDM  2019-10-23           -0.377778  46033103.0  4.5000
# ..    ...         ...                 ...         ...     ...
# 979   CGA  2020-10-07           -0.326996   4397025.0  2.6300
# 980  RAVE  2020-10-07           -0.535588  15942834.0  1.9810
# 981  SNMP  2020-10-09           -0.408000  10780254.0  1.2500
# 982  USWS  2020-10-09           -0.341400  38945400.0  0.5785
# 983  MDLY  2020-10-12           -0.630951    621958.0  2.6300
#
#      1stTrancheVolume  2ndTrancheVolume  1stTranchePercent  \
# 0             20912.0            1161.0           0.947402
# 1             89569.0           11137.0           0.889411
# ...

# %%
selectedAtivosDiasDF.to_excel("adl_reverse_df.xlsx")
