# %%
# https://www.w3schools.com/python/python_mysql_getstarted.asp
# referência mais simples impossível

# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password=""
)

# %%
print(mydb)

# %%
mycursor = mydb.cursor(dictionary=True)

mycursor.execute("SHOW DATABASES")

for x in mycursor:
  print(x)

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="moneyland"
)

# %%
mycursor = mydb.cursor()

mycursor.execute("SHOW TABLES")

for x in mycursor:
  print(x)

# %%
mycursor = mydb.cursor(dictionary=True)

mycursor.execute("SELECT * FROM trades WHERE symbol='ABUS' AND DATE(trade_timestamp) = '2020-07-24'")

myresult = mycursor.fetchall()

myresult

# %%
data = []
for x in myresult:
    bar

# %%
for x in myresult:
  print(x)

# %%
myresult

# %%
mylist = myresult.copy()

# %%
mylist

# %%
[{k: v for k, v in d.iteritems() if k != 'mykey1'} for d in mylist]

# %%
import os
os.chdir('../')

# %%
from pynnystock.settings import db

# %%
db['host']
db['user']
db['password']

# %%
mydb = mysql.connector.connect(
  host=db['host'],
  user=db['user'],
  password=db['password']
)

# %%
m = myresult[0]
m

# %%
bar = {
    'time': m['trade_timestamp'],
    'open': m['open'],
    'high': m['high'],
    'low': m['low'],
    'close': m['close'],
    'volume': m['volume']
}
bar

# %%
mydb.close()

# %%
x = 'ABUS'
f"SELECT * FROM trades WHERE symbol='{x}'"

# %% [markdown]
# #### E como pegar a lista de nomes direto do banco de dados?

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="moneyland"
)

# %%
#mycursor = mydb.cursor(dictionary=True)
mycursor = mydb.cursor()
mycursor.execute("SELECT DISTINCT symbol from trades")
myresult = mycursor.fetchall()
myresult
# Out:
# [('AAME',),
#  ('AAOI',),
#  ('AAON',),
#  ('AAWW',),
#  ('AAXN',),
#  ('ABCB',),
#  ('ABCL',),
#  ('ABEO',),
#  ('ABIO',),
#  ('ABMD',),
#  ('ABNB',),
#  ('ABST',),
#  ('ABTX',),
#  ('ABUS',),
#  ('ACAD',),
#  ('ACAM',),
#  ('ACAMU',),
#  ('ACBI',),
#  ('ACCD',),
#  ('ACER',),
#  ('ACET',),
#  ('ACHC',),
#  ('ACHV',),
#  ('ACIA',),
#  ('ACIU',),
#  ('ACIW',),
#  ('ACLS',),
#  ('ACMR',),
#  ('ACNB',),
#  ('ACOR',),
#  ('ACRS',),
#  ('ACRX',),
#  ('ACST',),
#  ('ACTG',),
#  ('ADAP',),
#  ('ADES',),
#  ('ADIL',),
#  ('ADMA',),
#  ('ADMP',),
#  ('ADMS',),
#  ('ADPT',),
#  ('ADSK',),
#  ('ADTN',),
#  ('ADTX',),
#  ('ADUS',),
#  ('ADVM',),
#  ('ADXS',),
#  ('AEGN',),
#  ('AEHL',),
#  ('AEHR',),
#  ('AEIS',),
#  ('AEMD',),
#  ('AERI',),
#  ('AESE',),
#  ('AEY',),
#  ('AEYE',),
#  ('AEZS',),
#  ('AFIB',),
#  ('AFIN',),
#  ('AFINP',),
#  ('AFMD',),
#  ('AFYA',),
#  ('AGBA',),
#  ('AGEN',),
#  ('AGFS',),
#  ('AGIO',),
#  ('AGLE',),
#  ('AGMH',),
#  ('AGRX',),
#  ('AGTC',),
#  ('AGYS',),
# ...

# %%
mydb.close()

# %%
# pergunta, como converter uma list of tuples em uma list? às vezes as tuples podem ter mais de 1 elemento, mas nesse
# caso não irão ter
# https://www.geeksforgeeks.org/python-convert-list-of-tuples-into-list/

# myresult[13][0] # 'ABUS'

# A maneira mais fácil de cumprir a tarefa é usando list comprehensions

# %%
names = [item for t in myresult for item in t]

# %%
names[2600:]
# Out:
# ['USAT',
#  'USAU',
#  'USCR',
#  'USEG',
#  'USIO',
#  'USLM',
#  'USWS',
#  'UTHR',
#  'UTMD',
#  'UTSI',
#  'UVSP',
#  'UXIN',
#  'VALU',
#  'VBFC',
#  'VBIV',
#  'VBLT',
#  'VBTX',
#  'VC',
#  'VCEL',
#  'VCNX',
#  'VCTR',
#  'VCYT',
#  'VECO',
#  'VERB',
#  'VERI',
#  'VERO',
#  'VERU',
#  'VERX',
#  'VERY',
#  'VFF',
#  'VG',
#  'VIACA',
#  'VIAV',
#  'VICR',
#  'VIE',
#  'VIOT',
#  'VIR',
#  'VIRC',
#  'VIRI',
#  'VIRT',
#  'VISL',
#  'VITL',
#  'VIVE',
#  'VIVO',
#  'VKTX',
#  'VLDR',
#  'VLGEA',
#  'VMAR',
#  'VMD',
#  'VNDA',
#  'VNET',
#  'VNOM',
#  'VOXX',
#  'VRA',
#  'VRAY',
#  'VRCA',
#  'VREX',
#  'VRM',
#  'VRME',
#  'VRNA',
#  'VRNS',
#  'VRNT',
#  'VRRM',
#  'VRSK',
#  'VRSN',
#  'VRTS',
#  'VRTU',
#  'VRTX',
#  'VSAT',
#  'VSEC',
#  'VSTA',
#  'VSTM',
#  'VTGN',
#  'VTNR',
#  'VTRU',
#  'VTSI',
#  'VTVT',
#  'VUZI',
#  'VVPR',
#  'VXRT',
#  'VYGR',
#  'VYNE',
#  'WABC',
#  'WAFD',
#  'WAFU',
#  'WASH',
#  'WATT',
#  'WB',
#  'WDAY',
#  'WDC',
#  'WDFC',
#  'WEN',
# ...
